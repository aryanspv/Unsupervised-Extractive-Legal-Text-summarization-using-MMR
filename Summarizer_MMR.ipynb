# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk
# !pip install segment_tree
from segment_tree import *
from sklearn.feature_extraction.text import TfidfVectorizer
from __future__ import unicode_literals, print_function
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import spacy
import re
# !pip install rouge
from rouge import Rouge 
from collections import OrderedDict
import string
import numpy as np
from spacy.lang.en import English
import time
nl = English()
import sys
import pandas as pd

repeat = 5
data = []
doc = []
l3 = []
summary = []
hypothesis = ""
word_count = []
pair_similarity = []
summary_string = []
segtree_array = []
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: segment_tree in /usr/local/lib/python3.8/dist-packages (0.3.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rouge in /usr/local/lib/python3.8/dist-packages (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from rouge) (1.15.0)

# %%
def count_word(index):
    global doc
    Doc = nl(doc[index])
    tokens = [t.text for t in Doc]
    tokens = [t for t in tokens if len(t.translate(t.maketrans('', '', string.punctuation + string.whitespace))) > 0] # + string.digits
    return len(tokens)

# %%
def store_word_count():
    global word_count,doc
    word_count = []
    for i in range(0,len(doc)):
        word_count.append(count_word(i))

# %%
def maximum(index, toPrint=0):
    global summary, pair_similarity
    length = len(summary)
    if(length!=0):
        max=0
        for i in range(length):
            a=pair_similarity[index][summary[i]]
            if(a>max):
                max=a
            if toPrint:
              print(str(summary[i])+" -> "+str(a))
        return max
    else:
        return 0

# %%
def count_sum(summary):
    sum=0
    length = len(summary)
    for i in range(length):
        sum+=count_word(summary[i])
    return sum

# %%
def mmr_sorted(lambda_, y, length):
    global word_count, pair_similarity, summary, segtree_array
    print('Inside MMR')
    l3 = []
    # vectorizer = TfidfVectorizer(smooth_idf=False)
    # X = vectorizer.fit_transform(doc)
    # y = X.toarray()
    rows = len(y)
    pair_similarity = []
    for i in range(rows):
        max=-1
        pair_similarity.append([])
        for j in range(rows):
            if(j!=i):
                a = np.sum(np.multiply(y[i],y[j]))
                pair_similarity[-1].append(a)
                if(a>max):
                    max=a
            else:
                pair_similarity[-1].append(1)
        l3.append(max)
    store_word_count()
    l = rows 
    count = 0
    last = -1
    summary = []
    summary_word_count = 0
    while(1):
        # print(summary_word_count)
        if (summary_word_count < length):
            max=-1
            for i in range(l):
                # a = maximum(i)
                a = segtree_array[i].query(0,rows-1,"max")
                mmrscore = lambda_*l3[i] - (1-lambda_)*a
                if(mmrscore >= max):
                    max = mmrscore
                    ind = i
            summary.append(ind)
            summary_word_count += word_count[ind]
            for i in range(l):
                segtree_array[i].update(ind,pair_similarity[i][ind])
        else:
            print('Bye')
            break

# %%
def listToString():  
    global summary_string, word_count, hypothesis, summary, doc
    summary_string = []
    leng = 0
    for i in summary:
      summary_string.append(doc[i])
      leng += word_count[i]
    hypothesis = "".join(summary_string) 

rouge_A1_avg = [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]
rouge_A2_avg = [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]

X1 = pd.read_csv('/content/drive/MyDrive/Unsupervised-Extractive-Legal-Document-Summarization-master/Datasets/indian-summary-len-a1.txt', sep="\s", header=None)
X2 = pd.read_csv('/content/drive/MyDrive/Unsupervised-Extractive-Legal-Document-Summarization-master/Datasets/indian-summary-len-a2.txt', sep="\s", header=None)

AllDocs = []
for i in range(0,50):
  with open(r'/content/drive/MyDrive/Unsupervised-Extractive-Legal-Document-Summarization-master/Datasets/sentence_splitted/'+X1[0][i], 'r') as file:
    AllDocs.append(file.read().replace('\n',' '))
tf = TfidfVectorizer(smooth_idf=False)
X = tf.fit_transform(AllDocs)

rouge = Rouge()
sys.setrecursionlimit(429496729)
for i in range(0,50):
  length1=X1[1][i]
  length2=X2[1][i]
  doc = []
  y = []
  zeros = []
  segtree_array = []
  with open(r'/content/drive/MyDrive/Unsupervised-Extractive-Legal-Document-Summarization-master/Datasets/sentence_splitted/'+X1[0][i], 'r') as file:
    for x in file:
      if x != '\n':
        doc.append(x)
        y.append(tf.transform([x]).toarray()[0])
        zeros.append(0)
  for i1 in range(len(y)):
    segtree_array.append(SegmentTree(zeros))
  with open(r'/content/drive/MyDrive/Unsupervised-Extractive-Legal-Document-Summarization-master/Datasets/A1/'+X1[0][i],'r') as file:
    reference1 = file.read()

  with open(r'/content/drive/MyDrive/Unsupervised-Extractive-Legal-Document-Summarization-master/Datasets/A2/'+X2[0][i], 'r') as file:
    reference2 = file.read()
  lamda=[0.3,0.5,0.7]
  for j in lamda:
    mmr_sorted(j,y,length1)
    listToString()
    print("Processing -> "+"sumA1_"+X1[0][i][:-4]+'_'+str(j)+".txt")
    f= open(r'/content/drive/MyDrive/Unsupervised-Extractive-Legal-Document-Summarization-master/Results/A1sum/'+"sumA1_"+X1[0][i][:-4]+'_'+str(j)+".txt","w+")
    n = f.write(hypothesis)
    f.close()
    scores = rouge.get_scores(hypothesis, reference1)
    u = len(scores)
    for i1 in range(u):
      for k, v in scores[i1].items():
        for k_, v_ in v.items():
          rouge_A1_avg[i1][k][k_] += v_*0.02/3.0
    g= open("rogue.txt","a+")
    n = g.write(X1[0][i][:-4]+'\t'+"A1 - "+str(j)+'\t'+str(scores)+'\n')
    g.close()
    hypothesis=""
  for j in lamda:
    mmr_sorted(j,y,length2)
    listToString()
    print("Processing -> "+"sumA2_"+X2[0][i][:-4]+'_'+str(j)+".txt")
    f= open(r'/content/drive/MyDrive/Unsupervised-Extractive-Legal-Document-Summarization-master/Results/A2sum/'+"sumA2_"+X2[0][i][:-4]+'_'+str(j)+".txt","w+")
    n = f.write(hypothesis)
    f.close()
    scores = rouge.get_scores(hypothesis, reference2)
    u = len(scores)
    for i1 in range(u):
      for k, v in scores[i1].items():
        for k_, v_ in v.items():
          rouge_A2_avg[i1][k][k_] += v_*0.02/3.0
    g= open("rogue.txt","a+")
    n = g.write(X2[0][i][:-4]+'\t'+"A2 - "+str(j)+'\t'+str(scores)+'\n')
    g.close()
print("Rouge A1 average :-")
print(rouge_A1_avg)
print("Rouge A2 average :-")
print(rouge_A2_avg)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# Inside MMR
# Bye
# Processing -> sumA1_1953_L_1_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1953_L_1_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1953_L_1_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1953_L_1_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1953_L_1_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1953_L_1_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1953_S_23_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1953_S_23_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1953_S_23_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1953_S_23_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1953_S_23_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1953_S_23_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1954_M_25_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1954_M_25_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1954_M_25_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1954_M_25_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1954_M_25_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1954_M_25_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1963_S_59_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1963_S_59_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1963_S_59_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1963_S_59_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1963_S_59_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1963_S_59_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1971_S_1_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1971_S_1_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1971_S_1_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1971_S_1_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1971_S_1_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1971_S_1_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1973_S_68_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1973_S_68_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1973_S_68_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1973_S_68_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1973_S_68_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1973_S_68_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1976_T_9_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1976_T_9_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1976_T_9_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1976_T_9_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1976_T_9_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1976_T_9_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1977_P_19_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1977_P_19_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1977_P_19_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1977_P_19_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1977_P_19_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1977_P_19_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1978_M_13_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1978_M_13_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1978_M_13_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1978_M_13_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1978_M_13_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1978_M_13_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1980_W_3_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1980_W_3_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1980_W_3_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1980_W_3_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1980_W_3_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1980_W_3_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_C_108_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_C_108_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_C_108_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_C_108_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_C_108_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_C_108_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_M_123_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_M_123_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_M_123_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_M_123_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_M_123_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_M_123_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_S_26_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_S_26_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1987_S_26_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_S_26_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_S_26_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1987_S_26_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1989_A_55_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1989_A_55_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1989_A_55_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1989_A_55_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1989_A_55_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1989_A_55_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1994_M_69_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1994_M_69_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1994_M_69_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1994_M_69_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1994_M_69_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1994_M_69_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1994_S_246_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1994_S_246_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1994_S_246_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1994_S_246_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1994_S_246_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1994_S_246_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1995_S_317_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1995_S_317_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1995_S_317_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1995_S_317_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1995_S_317_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1995_S_317_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1996_B_72_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1996_B_72_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1996_B_72_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1996_B_72_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1996_B_72_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1996_B_72_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_1996_T_169_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_1996_T_169_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_1996_T_169_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_1996_T_169_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_1996_T_169_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_1996_T_169_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2000_C_151_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2000_C_151_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2000_C_151_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2000_C_151_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2000_C_151_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2000_C_151_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2000_V_80_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2000_V_80_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2000_V_80_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2000_V_80_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2000_V_80_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2000_V_80_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2001_A_234_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2001_A_234_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2001_A_234_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2001_A_234_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2001_A_234_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2001_A_234_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2001_S_1131_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2001_S_1131_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2001_S_1131_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2001_S_1131_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2001_S_1131_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2001_S_1131_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2004_C_129_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2004_C_129_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2004_C_129_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2004_C_129_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2004_C_129_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2004_C_129_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2004_I_24_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2004_I_24_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2004_I_24_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2004_I_24_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2004_I_24_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2004_I_24_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2005_S_388_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2005_S_388_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2005_S_388_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2005_S_388_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2005_S_388_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2005_S_388_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2006_A_136_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2006_A_136_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2006_A_136_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2006_A_136_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2006_A_136_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2006_A_136_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2006_A_36_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2006_A_36_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2006_A_36_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2006_A_36_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2006_A_36_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2006_A_36_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_B_76_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_B_76_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_B_76_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_B_76_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_B_76_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_B_76_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_C_121_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_C_121_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_C_121_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_C_121_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_C_121_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_C_121_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_S_608_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_S_608_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_S_608_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_S_608_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_S_608_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_S_608_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_S_632_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_S_632_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_S_632_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_S_632_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_S_632_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_S_632_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_U_18_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_U_18_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2007_U_18_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_U_18_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_U_18_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2007_U_18_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_A_260_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_A_260_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_A_260_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_A_260_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_A_260_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_A_260_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_C_166_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_C_166_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_C_166_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_C_166_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_C_166_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_C_166_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_I_54_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_I_54_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_I_54_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_I_54_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_I_54_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_I_54_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_P_8_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_P_8_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_P_8_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_P_8_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_P_8_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_P_8_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_S_1411_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_S_1411_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_S_1411_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_S_1411_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_S_1411_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_S_1411_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_S_549_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_S_549_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2008_S_549_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_S_549_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_S_549_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2008_S_549_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2009_B_16_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2009_B_16_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2009_B_16_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2009_B_16_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2009_B_16_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2009_B_16_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2009_S_146_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2009_S_146_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2009_S_146_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2009_S_146_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2009_S_146_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2009_S_146_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2010_J_55_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2010_J_55_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2010_J_55_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2010_J_55_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2010_J_55_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2010_J_55_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2010_S_431_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2010_S_431_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2010_S_431_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2010_S_431_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2010_S_431_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2010_S_431_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2011_I_16_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2011_I_16_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2011_I_16_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2011_I_16_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2011_I_16_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2011_I_16_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2011_S_308_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2011_S_308_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2011_S_308_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2011_S_308_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2011_S_308_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2011_S_308_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2012_S_270_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2012_S_270_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2012_S_270_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2012_S_270_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2012_S_270_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2012_S_270_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2014_J_33_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2014_J_33_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2014_J_33_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2014_J_33_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2014_J_33_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2014_J_33_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2014_R_41_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2014_R_41_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2014_R_41_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2014_R_41_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2014_R_41_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2014_R_41_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2015_J_10_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2015_J_10_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2015_J_10_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2015_J_10_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2015_J_10_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2015_J_10_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA1_2015_S_368_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA1_2015_S_368_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA1_2015_S_368_0.7.txt
# Inside MMR
# Bye
# Processing -> sumA2_2015_S_368_0.3.txt
# Inside MMR
# Bye
# Processing -> sumA2_2015_S_368_0.5.txt
# Inside MMR
# Bye
# Processing -> sumA2_2015_S_368_0.7.txt
# Rouge A1 average :-
# [{'rouge-1': {'f': 0.40396110828756715, 'p': 0.57346579250939, 'r': 0.40845282550885703}, 'rouge-2': {'f': 0.27304257707969526, 'p': 0.352098919530786, 'r': 0.2739813287156291}, 'rouge-l': {'f': 0.38576526150670865, 'p': 0.5525140405846032, 'r': 0.389963199046205}}]
# Rouge A2 average :-
# [{'rouge-1': {'f': 0.26293993597965004, 'p': 0.6749972781520319, 'r': 0.2326119205138305}, 'rouge-2': {'f': 0.1708024158765131, 'p': 0.4159758373483399, 'r': 0.1521466665306909}, 'rouge-l': {'f': 0.2506901887795404, 'p': 0.6542872201625015, 'r': 0.22149935003448903}}]
